# %% [markdown]
# # Data splitting & preprocessing

# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/cleaned_merged_seasons.csv')
# Out:
# /Users/SulMac/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Imputing categorical missing values

# %%
categorical_features = df.select_dtypes(include = ['object']).columns.values
categorical_features
# Out:
# array(['season_x', 'name', 'position', 'team_x', 'kickoff_time',
#        'opp_team_name'], dtype=object)

# %%
from sklearn.impute import SimpleImputer
cat_impute = SimpleImputer(strategy='constant', fill_value = 'missing')

# %%
df[categorical_features].head()
# Out:
#   season_x                name position team_x          kickoff_time  \
# 0  2016-17     Aaron Cresswell      DEF    NaN  2016-08-15T19:00:00Z
# 1  2016-17        Aaron Lennon      MID    NaN  2016-08-13T14:00:00Z
# 2  2016-17        Aaron Ramsey      MID    NaN  2016-08-14T15:00:00Z
# 3  2016-17  Abdoulaye Doucouré      MID    NaN  2016-08-13T14:00:00Z
# 4  2016-17        Adam Forshaw      MID    NaN  2016-08-13T14:00:00Z
#
#   opp_team_name
# 0       Chelsea
# 1         Spurs
# 2     Liverpool
# 3   Southampton
# 4         Stoke

# %%
cat_impute.fit(df[categorical_features])
# Out:
# SimpleImputer(fill_value='missing', strategy='constant')

# %%
df[categorical_features] = cat_impute.transform(df[categorical_features])

# %%
df[categorical_features].isnull().sum()
# Out:
# season_x         0
# name             0
# position         0
# team_x           0
# kickoff_time     0
# opp_team_name    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 season_x                name position   team_x  assists  bonus  \
# 0           0  2016-17     Aaron Cresswell      DEF  missing        0      0
# 1           1  2016-17        Aaron Lennon      MID  missing        0      0
# 2           2  2016-17        Aaron Ramsey      MID  missing        0      0
# 3           3  2016-17  Abdoulaye Doucouré      MID  missing        0      0
# 4           4  2016-17        Adam Forshaw      MID  missing        0      0
#
#    bps  clean_sheets  creativity  ...  team_h_score  threat  total_points  \
# 0    0             0         0.0  ...           2.0     0.0             0
# 1    6             0         0.3  ...           1.0     0.0             1
# 2    5             0         4.9  ...           3.0    23.0             2
# 3    0             0         0.0  ...           1.0     0.0             0
# 4    3             0         1.3  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# 0                  0             0              0    55     False
# 1                  0             0              0    60      True
# 2                  0             0              0    80      True
# 3                  0             0              0    50     False
# 4                  0             0              0    45      True
#
#    yellow_cards GW
# 0             0  1
# 1             0  1
# 2             0  1
# 3             0  1
# 4             1  1
#
# [5 rows x 38 columns]

# %%
df["team_x"]
# Out:
# 0            missing
# 1            missing
# 2            missing
# 3            missing
# 4            missing
#             ...
# 98397      Leicester
# 98398      Newcastle
# 98399    Southampton
# 98400       Brighton
# 98401       West Ham
# Name: team_x, Length: 98402, dtype: object

# %% [markdown]
# # Splitting CSV File by season_x column

# %%
#Here we want to check the unique values in "season_X" column
unique_val = df['season_x'].unique()
unique_val
# Out:
# array(['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22'],
#       dtype=object)

# %%
#We want to use the data of 2021-22 season as a test data 
df_output = df[df['season_x'].str.contains('2021-22')]
#We creating a new .CSV file with the name Test 
df_path = os.path.join('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Test' ,'Test' + '.csv' )
df_output.to_csv(df_path)

# %%
#Importing our new Test.csv
testdf = pd.read_csv('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Test/Test.csv')

# %%
testdf.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 season_x                           name position  \
# 0       73837         73837  2021-22                    Eric Bailly      DEF
# 1       73838         73838  2021-22                   Keinan Davis      FWD
# 2       73839         73839  2021-22         Ayotomiwa Dele-Bashiru      MID
# 3       73840         73840  2021-22              James Ward-Prowse      MID
# 4       73841         73841  2021-22  Bruno Miguel Borges Fernandes      MID
#
#         team_x  assists  bonus  bps  clean_sheets  ...  team_h_score  threat  \
# 0      Man Utd        0      0    0             0  ...           5.0     0.0
# 1  Aston Villa        0      0    0             0  ...           3.0     0.0
# 2      Watford        0      0    0             0  ...           3.0     0.0
# 3  Southampton        0      0   20             0  ...           3.0     0.0
# 4      Man Utd        0      3   61             0  ...           5.0    59.0
#
#    total_points  transfers_balance  transfers_in  transfers_out  value  \
# 0             0                  0             0              0     50
# 1             0                  0             0              0     45
# 2             0                  0             0              0     45
# 3             2                  0             0              0     65
# 4            20                  0             0              0    120
#
#   was_home  yellow_cards  GW
# 0     True             0   1
# 1    False             0   1
# 2     True             0   1
# 3    False             0   1
# 4     True             0   1
#
# [5 rows x 39 columns]

# %%
#Checking if it contains any value from another seasons 
Testunique_val = testdf['season_x'].unique()
Testunique_val
# Out:
# array(['2021-22'], dtype=object)

# %% [markdown]
# # Creating a train dataset excluding rows contains 2021-22

# %%
#Here we define the x as the excluding start point
x = 73837
#Y is where we want to stop .
y = 98401
df.loc[x:y]

df.loc[x:y].index
# Out:
# RangeIndex(start=73837, stop=98402, step=1)

# %%
#Dropping the rows between 73837 and 98401
dftrain = df.drop(df.loc[x:y].index, inplace=False)
#Saving the new dataframe into a CSV file with the name Train.csv
df_tpath = os.path.join('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Train' ,'Train' + '.csv' )
dftrain.to_csv(df_tpath)

# %%
#Importing our new dataset
dft = pd.read_csv('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Train/Train.csv')

# %%
dft.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 season_x                name position   team_x  \
# 0           0             0  2016-17     Aaron Cresswell      DEF  missing
# 1           1             1  2016-17        Aaron Lennon      MID  missing
# 2           2             2  2016-17        Aaron Ramsey      MID  missing
# 3           3             3  2016-17  Abdoulaye Doucouré      MID  missing
# 4           4             4  2016-17        Adam Forshaw      MID  missing
#
#    assists  bonus  bps  clean_sheets  ...  team_h_score  threat  total_points  \
# 0        0      0    0             0  ...           2.0     0.0             0
# 1        0      0    6             0  ...           1.0     0.0             1
# 2        0      0    5             0  ...           3.0    23.0             2
# 3        0      0    0             0  ...           1.0     0.0             0
# 4        0      0    3             0  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in  transfers_out  value was_home  \
# 0                  0             0              0     55    False
# 1                  0             0              0     60     True
# 2                  0             0              0     80     True
# 3                  0             0              0     50    False
# 4                  0             0              0     45     True
#
#    yellow_cards  GW
# 0             0   1
# 1             0   1
# 2             0   1
# 3             0   1
# 4             1   1
#
# [5 rows x 39 columns]

# %%
dft.tail()
# Out:
#        Unnamed: 0  Unnamed: 0.1 season_x                  name position  \
# 73832       73832         73832  2020-21        Aaron Ramsdale       GK
# 73833       73833         73833  2020-21          Adrien Silva      MID
# 73834       73834         73834  2020-21        Sidnei Tavares      MID
# 73835       73835         73835  2020-21       Kalvin Phillips      MID
# 73836       73836         73836  2020-21  Raphael Dias Belloli      MID
#
#               team_x  assists  bonus  bps  clean_sheets  ...  team_h_score  \
# 73832  Sheffield Utd        0      2   30             1  ...           1.0
# 73833      Leicester        0      0    0             0  ...           2.0
# 73834      Leicester        0      0    0             0  ...           2.0
# 73835          Leeds        0      0   17             0  ...           3.0
# 73836          Leeds        1      0   24             0  ...           3.0
#
#        threat  total_points  transfers_balance  transfers_in  transfers_out  \
# 73832     0.0             9              13618         17381           3763
# 73833     0.0             0                -16             0             16
# 73834     0.0             0                 32            60             28
# 73835     8.0             6                210           789            579
# 73836    31.0             5             124979        142069          17090
#
#        value was_home  yellow_cards  GW
# 73832     46     True             0  38
# 73833     44     True             0  38
# 73834     44     True             0  38
# 73835     49     True             1  38
# 73836     56     True             0  38
#
# [5 rows x 39 columns]

# %%
#To check that we removed every row that contains 2021-22 in season_x column
unique_val = dft['season_x'].unique()
unique_val
# Out:
# array(['2016-17', '2017-18', '2018-19', '2019-20', '2020-21'],
#       dtype=object)

# %% [markdown]
# # Removing unwanted columns and write it to the existing CSV files

# %%
#Dropping columns that we won't use in train dataset
dft.drop(['kickoff_time'],axis=1,inplace=True)
dft.drop(['Unnamed: 0'],axis=1,inplace=True)
dft.drop(['Unnamed: 0.1'],axis=1,inplace=True)
#Saving it to Train.csv
dft.to_csv('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Train/Train.csv')


#Dropping columns that we won't use in test dataset
testdf.drop(['kickoff_time'],axis=1,inplace=True)
testdf.drop(['Unnamed: 0'],axis=1,inplace=True)
testdf.drop(['Unnamed: 0.1'],axis=1,inplace=True)
#Saving it to Test.csv
testdf.to_csv('/Users/SulMac/Desktop/MiskDSI/FPL/Best-FPL-team-predictor/Data/Test/Test.csv')
